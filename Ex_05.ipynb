# %% [markdown]
# <a href="https://colab.research.google.com/github/arshatha-palanivel/-SOLUTION-TO-A-SYSTEM-OF-LINEAR-EQUATIONS/blob/main/Ex_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('Encoding Data.csv')
df.head()
# Out:
#    id bin_1 bin_2  nom_0 ord_2
# 0   0     F     N    Red   Hot
# 1   1     F     Y   Blue  Warm
# 2   2     F     N   Blue  Cold
# 3   3     F     N  Green  Warm
# 4   4     T     N    Red  Cold

# %%
df['ord_2'].unique()
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
climate = ['Cold','Warm','Hot']
en= OrdinalEncoder(categories = [climate])
df['ord_2']=en.fit_transform(df[["ord_2"]])
df
# Out:
#    id bin_1 bin_2  nom_0  ord_2
# 0   0     F     N    Red    2.0
# 1   1     F     Y   Blue    1.0
# 2   2     F     N   Blue    0.0
# 3   3     F     N  Green    1.0
# 4   4     T     N    Red    0.0
# 5   5     T     N  Green    2.0
# 6   6     F     N    Red    0.0
# 7   7     T     N    Red    0.0
# 8   8     F     N   Blue    1.0
# 9   9     F     Y    Red    2.0

# %%
le = LabelEncoder()
df['Nom_0'] = le.fit_transform(df[["nom_0"]])
df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    id bin_1 bin_2  nom_0  ord_2  Nom_0
# 0   0     F     N    Red    2.0      2
# 1   1     F     Y   Blue    1.0      0
# 2   2     F     N   Blue    0.0      0
# 3   3     F     N  Green    1.0      1
# 4   4     T     N    Red    0.0      2
# 5   5     T     N  Green    2.0      1
# 6   6     F     N    Red    0.0      2
# 7   7     T     N    Red    0.0      2
# 8   8     F     N   Blue    1.0      0
# 9   9     F     Y    Red    2.0      2

# %%
df  = pd.concat([df,data],axis=1)
df
# Out:
#    id bin_1 bin_2  nom_0  ord_2  Nom_0  bin_1_0  bin_1_1  bin_2_0  bin_2_1  \
# 0   0     F     N    Red    2.0      2        0        1        0        1
# 1   1     F     Y   Blue    1.0      0        0        1        1        0
# 2   2     F     N   Blue    0.0      0        0        1        0        1
# 3   3     F     N  Green    1.0      1        0        1        0        1
# 4   4     T     N    Red    0.0      2        1        0        0        1
# 5   5     T     N  Green    2.0      1        1        0        0        1
# 6   6     F     N    Red    0.0      2        0        1        0        1
# 7   7     T     N    Red    0.0      2        1        0        0        1
# 8   8     F     N   Blue    1.0      0        0        1        0        1
# 9   9     F     Y    Red    2.0      2        0        1        1        0
#
#    bin_2_0  bin_2_1
# 0        0        1
# 1        1        0
# 2        0        1
# 3        0        1
# 4        0        1
# ...

# %%
be = BinaryEncoder()
data = be.fit_transform(df['bin_1'])
df
# Out:
#    id bin_1 bin_2  nom_0  ord_2  Nom_0  bin_1_0  bin_1_1  bin_2_0  bin_2_1  \
# 0   0     F     N    Red    2.0      2        0        1        0        1
# 1   1     F     Y   Blue    1.0      0        0        1        1        0
# 2   2     F     N   Blue    0.0      0        0        1        0        1
# 3   3     F     N  Green    1.0      1        0        1        0        1
# 4   4     T     N    Red    0.0      2        1        0        0        1
# 5   5     T     N  Green    2.0      1        1        0        0        1
# 6   6     F     N    Red    0.0      2        0        1        0        1
# 7   7     T     N    Red    0.0      2        1        0        0        1
# 8   8     F     N   Blue    1.0      0        0        1        0        1
# 9   9     F     Y    Red    2.0      2        0        1        1        0
#
#    bin_2_0  bin_2_1
# 0        0        1
# 1        1        0
# 2        0        1
# 3        0        1
# 4        0        1
# ...

# %%
be = BinaryEncoder()
data = be.fit_transform(df['bin_2'])
df  = pd.concat([df,data],axis=1)
df
# Out:
#    id bin_1 bin_2  nom_0  ord_2  Nom_0  bin_1_0  bin_1_1  bin_2_0  bin_2_1
# 0   0     F     N    Red    2.0      2        0        1        0        1
# 1   1     F     Y   Blue    1.0      0        0        1        1        0
# 2   2     F     N   Blue    0.0      0        0        1        0        1
# 3   3     F     N  Green    1.0      1        0        1        0        1
# 4   4     T     N    Red    0.0      2        1        0        0        1
# 5   5     T     N  Green    2.0      1        1        0        0        1
# 6   6     F     N    Red    0.0      2        0        1        0        1
# 7   7     T     N    Red    0.0      2        1        0        0        1
# 8   8     F     N   Blue    1.0      0        0        1        0        1
# 9   9     F     Y    Red    2.0      2        0        1        1        0

# %%
df1 = pd.read_csv("data.csv")
df1.head()
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target
# 0   0     F     N      Delhi       Hot  High School       0
# 1   1     F     Y  Bangalore      Warm      Masters       1
# 2   2     M     N     Mumbai  Very Hot      Diploma       1
# 3   3     M     Y    Chennai      Cold    Bachelors       0
# 4   4     M     Y      Delhi      Cold    Bachelors       1

# %%
df1['Ord_1'].unique()
climate = ['Cold','Warm','Hot','Very Hot']
en= OrdinalEncoder(categories = [climate])
df1['Ord_1']=en.fit_transform(df1[["Ord_1"]])
df1
# Out:
#    id bin_1 bin_2       City  Ord_1        Ord_2  Target
# 0   0     F     N      Delhi    2.0  High School       0
# 1   1     F     Y  Bangalore    1.0      Masters       1
# 2   2     M     N     Mumbai    3.0      Diploma       1
# 3   3     M     Y    Chennai    0.0    Bachelors       0
# 4   4     M     Y      Delhi    0.0    Bachelors       1
# 5   5     F     N      Delhi    3.0      Masters       0
# 6   6     M     N    Chennai    1.0          PhD       1
# 7   7     F     N    Chennai    2.0  High School       1
# 8   8     M     N      Delhi    3.0  High School       0
# 9   9     F     Y      Delhi    1.0          PhD       0

# %%
df1['Ord_2'].unique()
cl = ['High School','Diploma','Bachelors','Masters','PhD']
en= OrdinalEncoder(categories = [cl])
df1['Ord_2']=en.fit_transform(df1[["Ord_2"]])
df1
# Out:
#    id bin_1 bin_2       City  Ord_1  Ord_2  Target
# 0   0     F     N      Delhi    2.0    0.0       0
# 1   1     F     Y  Bangalore    1.0    3.0       1
# 2   2     M     N     Mumbai    3.0    1.0       1
# 3   3     M     Y    Chennai    0.0    2.0       0
# 4   4     M     Y      Delhi    0.0    2.0       1
# 5   5     F     N      Delhi    3.0    3.0       0
# 6   6     M     N    Chennai    1.0    4.0       1
# 7   7     F     N    Chennai    2.0    0.0       1
# 8   8     M     N      Delhi    3.0    0.0       0
# 9   9     F     Y      Delhi    1.0    4.0       0

# %%
le = LabelEncoder()
df1['City'] = le.fit_transform(df1[["City"]])
df1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#    id bin_1 bin_2  City  Ord_1  Ord_2  Target
# 0   0     F     N     2    2.0    0.0       0
# 1   1     F     Y     0    1.0    3.0       1
# 2   2     M     N     3    3.0    1.0       1
# 3   3     M     Y     1    0.0    2.0       0
# 4   4     M     Y     2    0.0    2.0       1
# 5   5     F     N     2    3.0    3.0       0
# 6   6     M     N     1    1.0    4.0       1
# 7   7     F     N     1    2.0    0.0       1
# 8   8     M     N     2    3.0    0.0       0
# 9   9     F     Y     2    1.0    4.0       0

# %%
from category_encoders import BinaryEncoder
be = BinaryEncoder()
dat = be.fit_transform(df1['bin_1'])
df1  = pd.concat([df1,dat],axis=1)
df1
# Out:
#    id bin_1 bin_2  City  Ord_1  Ord_2  Target  bin_1_0  bin_1_1
# 0   0     F     N     2    2.0    0.0       0        0        1
# 1   1     F     Y     0    1.0    3.0       1        0        1
# 2   2     M     N     3    3.0    1.0       1        1        0
# 3   3     M     Y     1    0.0    2.0       0        1        0
# 4   4     M     Y     2    0.0    2.0       1        1        0
# 5   5     F     N     2    3.0    3.0       0        0        1
# 6   6     M     N     1    1.0    4.0       1        1        0
# 7   7     F     N     1    2.0    0.0       1        0        1
# 8   8     M     N     2    3.0    0.0       0        1        0
# 9   9     F     Y     2    1.0    4.0       0        0        1

# %%
from category_encoders import BinaryEncoder
be = BinaryEncoder()
data1 = be.fit_transform(df1['bin_2'])
df1  = pd.concat([df1,data1],axis=1)
df1
# Out:
#    id bin_1 bin_2  City  Ord_1  Ord_2  Target  bin_1_0  bin_1_1  bin_2_0  \
# 0   0     F     N     2    2.0    0.0       0        0        1        0
# 1   1     F     Y     0    1.0    3.0       1        0        1        1
# 2   2     M     N     3    3.0    1.0       1        1        0        0
# 3   3     M     Y     1    0.0    2.0       0        1        0        1
# 4   4     M     Y     2    0.0    2.0       1        1        0        1
# 5   5     F     N     2    3.0    3.0       0        0        1        0
# 6   6     M     N     1    1.0    4.0       1        1        0        0
# 7   7     F     N     1    2.0    0.0       1        0        1        0
# 8   8     M     N     2    3.0    0.0       0        1        0        0
# 9   9     F     Y     2    1.0    4.0       0        0        1        1
#
#    bin_2_1
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
# 5        1
# 6        1
# 7        1
# 8        1
# 9        0

# %%
df2 = pd.read_csv("titanic_dataset.csv")
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
be = BinaryEncoder()
data2 = be.fit_transform(df2['Sex'])
df2  = pd.concat([df2,data2],axis=1)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.get_dummies(df2, prefix=['Embarked'] ,columns=['Embarked'])
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
